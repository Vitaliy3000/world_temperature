# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

pd.set_option('display.max_rows', 500)

# %%
filename = "world_temperature.json"

# %%
# URL = "https://en.wikipedia.org/wiki/List_of_cities_by_average_temperature"
# html = requests.get(URL).text
# soup = BeautifulSoup(html, "html.parser")
# tables = soup.findAll('tbody')

# data = []
# header = [th.text.strip() for th in tables[0].findAll("th")]

# for table in tables:
#     for tr in table.findAll("tr"):
#         if tr.findAll("td"):
#             data.append([td.text.strip().split("(")[0].replace("−", "-") for td in tr.findAll("td")])
            
# df = pd.DataFrame(data, columns=header)
# MONTHS = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
# df[MONTHS] = df[MONTHS].astype(float)
# df.to_json(filename)

# %%
df = pd.read_json(filename)

# %%
MIN_TEMPERATURE = 3
MAX_TEMPERATURE = 19
MIN_COUNT_MONTH = 12

# %%
df[df[MONTHS].apply(lambda x: x.apply(lambda y: MIN_TEMPERATURE <= y <= MAX_TEMPERATURE)).T.sum() >= MIN_COUNT_MONTH]
# Out:
#             Country              City   Jan   Feb   Mar   Apr   May   Jun  \
# 29          Eritrea            Asmara  13.8  14.9  16.3  17.0  17.6  17.6
# 32         Ethiopia       Addis Ababa  16.0  17.0  17.0  17.0  18.0  17.0
# 209         Belgium          Brussels   3.3   3.7   6.8   9.8  13.6  16.2
# 231         Ireland            Dublin   5.3   5.3   6.8   8.3  10.9  13.6
# 245     Netherlands         Amsterdam   3.4   3.5   6.1   9.1  12.9  15.4
# 275  United Kingdom         Edinburgh   4.2   4.5   6.2   8.1  10.8  13.5
# 276  United Kingdom            London   5.2   5.3   7.6   9.9  13.3  16.5
# 294          Canada         Vancouver   4.1   4.9   6.9   9.4  12.8  15.7
# 316          Mexico            Toluca   8.9  10.1  11.8  13.5  14.7  14.8
# 366   United States      SanFrancisco  11.2  12.6  13.3  13.9  14.7  15.8
# 368   United States           Seattle   5.4   6.2   7.9  10.1  13.2  15.9
# 382       Australia            Hobart  16.8  16.9  15.6  13.2  10.8   8.6
# ...

# %%
df[df["City"] == "Madrid"]
# Out:
#     Country    City  Jan  Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct  \
# 264   Spain  Madrid  6.3  7.9  11.2  12.9  16.7  22.2  25.6  25.1  20.9  15.1
#
#      Nov  Dec  Year   Ref.
# 264  9.9  6.9  15.0  [242]

# %%
df[df["City"] == "Moscow"]
# Out:
#     Country    City  Jan  Feb  Mar  Apr   May   Jun   Jul   Aug   Sep  Oct  \
# 254  Russia  Moscow -6.5 -6.7 -1.0  6.7  13.2  17.0  19.2  17.0  11.3  5.6
#
#      Nov  Dec Year   Ref.
# 254 -1.2 -5.2  5.8  [233]

# %%
df[df["City"] == "Prague"]
# Out:
#             Country    City  Jan  Feb  Mar  Apr   May   Jun   Jul   Aug   Sep  \
# 215  Czech Republic  Prague -1.4 -0.4  3.6  8.4  13.4  16.1  18.2  17.8  13.5
#
#      Oct  Nov  Dec Year   Ref.
# 215  8.5  3.1 -0.3  8.4  [196]

# %%
# df[df["Country"] == "Prague"]
# Out:
# Empty DataFrame
# Columns: [Country, City, Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec, Year, Ref.]
# Index: []
